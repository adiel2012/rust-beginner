# %% [markdown]
# # Chapter 20: Next Steps
# \n**Note:** This notebook will install Rust in your Colab environment. Run the setup cell first!\n
# Your journey with Rust continues!

# %%
# %%bash
# # Install Rust in Colab (run this cell first!)
# curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
# source $HOME/.cargo/env
# rustc --version

# %% [markdown]
# ## Contributing to Open Source
#
# Ways to contribute:
# - Fix bugs in existing crates
# - Add features to libraries you use
# - Improve documentation
# - Write blog posts and tutorials
# - Help others in forums and chat

# %% [markdown]
# ## Exploring the Rust Ecosystem
#
# Popular crates to explore:
# - **Web**: axum, actix-web, rocket
# - **Async**: tokio, async-std
# - **Serialization**: serde, bincode
# - **CLI**: clap, structopt
# - **Error handling**: anyhow, thiserror
# - **Database**: sqlx, diesel
# - **Testing**: proptest, criterion

# %% [markdown]
# ## Advanced Topics to Explore
#
# - Macros and procedural macros
# - Advanced trait usage
# - Embedded programming
# - WebAssembly with Rust
# - Game development (Bevy, Amethyst)
# - Systems programming
# - Blockchain development

# %% [markdown]
# ## Community Resources
#
# - **Official**: [rust-lang.org](https://www.rust-lang.org/)
# - **Documentation**: [doc.rust-lang.org](https://doc.rust-lang.org/)
# - **Forum**: [users.rust-lang.org](https://users.rust-lang.org/)
# - **Reddit**: [r/rust](https://www.reddit.com/r/rust/)
# - **Discord**: Rust Community Discord
# - **This Week in Rust**: Weekly newsletter

# %% [markdown]
# ## Recommended Practice Projects
#
# 1. **Command-line tool**: Build a grep clone or file searcher
# 2. **Web server**: Create a REST API or blog
# 3. **Game**: Simple 2D game with a game engine
# 4. **Database**: Implement a simple key-value store
# 5. **Parser**: Build a JSON or CSV parser
# 6. **Concurrent app**: Multi-threaded download manager
# 7. **WebAssembly**: Interactive web application

# %% [markdown]
# ## Career Paths with Rust
#
# - **Systems Programming**: Operating systems, databases
# - **Web Development**: Backend services, APIs
# - **Embedded Systems**: IoT devices, firmware
# - **Blockchain**: Cryptocurrency, smart contracts
# - **Game Development**: Game engines, tools
# - **DevOps**: CLI tools, infrastructure
# - **Cloud Services**: Serverless, microservices

# %% [markdown]
# ## Continue Learning
#
# ### Books
# - The Rust Programming Language (The Book)
# - Rust by Example
# - Programming Rust
# - Rust for Rustaceans
#
# ### Online Courses
# - Rustlings (interactive exercises)
# - Exercism Rust Track
# - YouTube tutorials
# - Udemy courses

# %% [markdown]
# ## Final Thoughts
#
# Congratulations on completing this Rust learning journey!
#
# Remember:
# - **Practice regularly** - Code every day, even if just for 30 minutes
# - **Build projects** - Apply what you've learned
# - **Read code** - Study well-written Rust projects
# - **Join the community** - Ask questions, help others
# - **Stay curious** - Rust is always evolving
#
# **Happy coding, Rustacean! 🦀**
